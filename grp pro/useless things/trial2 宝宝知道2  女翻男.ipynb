# %%
import pandas as pd 
import numpy as np

baobaozhidao2=pd.read_csv('宝宝知道2.csv')
baobaozhidao2
# Out:
#                               rs-line  \
# 0                      B超有没有的情况？15周5天
# 1                        四个多月b超 几率大吗？
# 2                             有没有的可能啊
# 3                    怀孕19周B超孩，有没有宝宝的？
# 4                             有的没有！！！
# ..                                ...
# 645                            谁知道是是类
# 646              哪位大佬帮我看看Nt检查是宝宝还是宝宝🙏
# 647                      有经验者请帮我看看是是😂
# 648  怀孕十周，孕囊74✖️33mm，顶臀径38.2mm，能看得出是是
# 649              请问一下各位亲们可以帮我解答一下是是吗？
#
#                                           rs-line href rs-line 2 rs-line 3  \
# 0    https://baobao.baidu.com/question/2413faa26937...         女         翻
# 1    https://baobao.baidu.com/question/42eb35342228...         男         翻
# 2    https://baobao.baidu.com/question/3fc949877438...         男         翻
# 3    https://baobao.baidu.com/question/60684c8abfa6...         男         男
# 4    https://baobao.baidu.com/question/ea28d5c702b8...         男         翻
# ...

# %%
baobaozhidao2.columns
# Out:
# Index(['rs-line', 'rs-line href', 'rs-line 2', 'rs-line 3', 'rs-line 4',
#        'rs-line 5', 'rs-line 6', 'time', 'answer', 'rs-line 7', 'rs-line 8'],
#       dtype='object')

# %%
to_drop=['rs-line href','rs-line 6','rs-line 7', 'rs-line 8']
baobaozhidao2.drop(columns=to_drop,inplace=True)
baobaozhidao2.columns
# Out:
# Index(['rs-line', 'rs-line 2', 'rs-line 3', 'rs-line 4', 'rs-line 5', 'time',
#        'answer'],
#       dtype='object')

# %%
df=baobaozhidao2
df
# Out:
#                               rs-line rs-line 2 rs-line 3 rs-line 4  \
# 0                      B超有没有的情况？15周5天         女         翻         男
# 1                        四个多月b超 几率大吗？         男         翻         女
# 2                             有没有的可能啊         男         翻         女
# 3                    怀孕19周B超孩，有没有宝宝的？         男         男         翻
# 4                             有的没有！！！         男         翻         女
# ..                                ...       ...       ...       ...
# 645                            谁知道是是类         男         女       NaN
# 646              哪位大佬帮我看看Nt检查是宝宝还是宝宝🙏         男         女       NaN
# 647                      有经验者请帮我看看是是😂         男         女       NaN
# 648  怀孕十周，孕囊74✖️33mm，顶臀径38.2mm，能看得出是是         男         女       NaN
# 649              请问一下各位亲们可以帮我解答一下是是吗？         男         女       NaN
#
#                                              rs-line 5         time answer
# 0    孕周16，实际15周5天，今天好奇去做了B超，医生看了大半天说看不清，位置不好，说是孩子背和...  2020年11月04日   1个回答
# ...

# %%
df['rs-line 4']= df['rs-line 4'].fillna('')
df['rs-line 5']= df['rs-line 5'].fillna('')
df
# Out:
#                               rs-line rs-line 2 rs-line 3 rs-line 4  \
# 0                      B超有没有的情况？15周5天         女         翻         男
# 1                        四个多月b超 几率大吗？         男         翻         女
# 2                             有没有的可能啊         男         翻         女
# 3                    怀孕19周B超孩，有没有宝宝的？         男         男         翻
# 4                             有的没有！！！         男         翻         女
# ..                                ...       ...       ...       ...
# 645                            谁知道是是类         男         女
# 646              哪位大佬帮我看看Nt检查是宝宝还是宝宝🙏         男         女
# 647                      有经验者请帮我看看是是😂         男         女
# 648  怀孕十周，孕囊74✖️33mm，顶臀径38.2mm，能看得出是是         男         女
# 649              请问一下各位亲们可以帮我解答一下是是吗？         男         女
#
#                                              rs-line 5         time answer
# 0    孕周16，实际15周5天，今天好奇去做了B超，医生看了大半天说看不清，位置不好，说是孩子背和...  2020年11月04日   1个回答
# ...

# %%
#还没做完。。。。做完再upload新版本
