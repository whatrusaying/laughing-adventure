# %%
import pandas as pd
csv = pd.read_csv(r"/Users/qianyi/Downloads/comments12.csv",encoding='utf-8')
df1= csv
df2 = df1.mark.value_counts()  
print(df2)
# Out:
# 3.7    1142
# 3.3     970
# 4.0     763
# 3.0     653
# 2.7     395
# 4.3     359
# 2.3     249
# 2.0     134
# 1.7      72
# 0.0      57
# 1.0      52
# Name: mark, dtype: int64

# %%
import matplotlib.pyplot as plt
labels = 'A range', 'B range', 'C range','Others'
X = [48, 41, 9,2]
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') 
plt.title("The percentage of different grades")
plt.show()

# %%
import pandas as pd


csv = pd.read_csv(r"/Users/qianyi/Downloads/comments12.csv",encoding='utf-8')
df1= csv
df2 = df1.region.value_counts()  
print(df2)
# Out:
# 1       3476
# 3       1292
# 2        115
# 老师本人       1
# Name: region, dtype: int64

# %%
import matplotlib.pyplot as plt

labels = 'local students', 'international students', 'mainland students'
X = [71, 26, 3]
colors = ["yellow","green","blue"]
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') 
plt.title("Proportion of students from different regions")
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
data1 = pd.read_csv(r"/Users/qianyi/Downloads/comments12.csv",encoding='utf-8')
data1 = data1.dropna(subset=["semester", "mark"])

sns.violinplot(data=data1, x="semester",y="mark", bw=.2, cut=2, linewidth=2)

# %%
import pandas as pd
data = pd.read_csv(r"/Users/qianyi/Downloads/comments12.csv")
data = data.dropna(subset=["year"])
data["year_num"] = data.apply(lambda row: row["year"][:5], axis=1)
plot_data = data.groupby("year_num")["year_num"].count()
plot_data.plot()

# %%
import pandas as pd


csv = pd.read_csv(r"/Users/qianyi/Downloads/comments12.csv",encoding='utf-8')
df1= csv
df2 = df1.teacher.value_counts()  
print(df2)
# Out:
# 李果                                                 40
# Raymond Wong                                       39
# Amy                                                37
# Wong Sai On                                        33
# 張為群                                                33
#                                                    ..
# TINDALL Eric                                        1
# Dr.Xin                                              1
# Melody Chong, Dennitza Gabrakova, Xiao-lin Wang     1
# alice                                               1
# 4個                                                  1
# Name: teacher, Length: 2198, dtype: int64

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

data1[data1["teacher"]=="李果"]["body"]
# Out:
# 11                       讀BBA，DSE 中文 5*，中史 5*，完全無問題，應付自如。
# 18                                      最緊要搵到好組員，最理想係文科底。
# 68                        同意上post既意見，教學認真和用心。\n讀cciv，揀雙李。
# 70      2019/20 Summer老師好有心機教，我覺得lecture同tutorial都一樣幾好...
# 112                                   cciv雙李，hea爆之選，誠意推介。
# 155                                    唔好信呢到d人話好grade+易讀。
# 351     著名講師李果。cciv都係add佢，兩課都係A。\n至於想學野，不了。走堂，hea過，靚gr...
# 382     難得reg到派grade hea底王，點知自已唔記得交其中一份assignment。lect...
# 390     如前面既人所講，我都係全走lecture，功課copy & paste，用pdf交，避過tu...
# 391     非常輕鬆，全走lecture，功課copy & paste，用pdf交，避過turnitin...
# 392     非常輕鬆，全走lecture，功課copy & paste，用pdf交，避過turnitin...
# 413     非常輕鬆，全走lecture，功課copy & paste，用pdf交，避過turnitin...
# 586                       好彩上年waitlist同班fd一齊入到，齊齊走堂，齊齊A-。
# 639                                       同另一課GE一齊讀，相得益彰。
# 640                                          成班同學一齊讀，齊齊A。
# 784                                          識reg一定reg李果。
# ...

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

data1[data1["teacher"]=="Raymond Wong"]["body"]
# Out:
# 176     我其實是先前留言2016/2017 Sem A 'F' grade 的同一個人，\n想更正 ...
# 177     -12 individual journals (500 words each)\n-no ...
# 364     更正翻：2018/19 SEM B考完Exam未出就知輕鬆靚龜，不過嗰Prof成日上堂講講下...
# 447     Workload:\nFood Diary Reflection (~1000word)\n...
# 846                     唔讀呢科你一定後悔\n勁易拎A+\n唔上堂都得,因為考試唔考筆記野
# 861     -Comment:Don't know what is learnt ... But gra...
# 914     40% 25題mc 錯4題 基本上係考raymond以外既prof同miss教既野\n60%...
# 917     成個學期得一份MC一份essay\n25題MC 40%\nessay 60% 上堂即場作(2...
# 982     入到黎就一定要溫書\n啊sir講d野好重要，我就係冇聽\n又冇去seminar，冇溫書，qu...
# 1063              20題MC+2000字report\n走左8成堂\nreport交左3500字
# 1070                        quiz+2000 word essayvery easy
# 1241    呢個sem 只係上堂take attendance同埋一份report\n---------...
# 1523    有一份MC Quiz 做落唔係太過難\n另外有份千字文要寫\n時間其實充足\n不過我太懶所以先B咗
# 1754    明明諗住可以揾呢科拉高CGPA，點知仲衰咗…今次真係中晒伏\n兩份assignment啲de...
# 1824    -上堂幾hea\n-上堂時Raymond 通常都係用廣東話, 有時會講英文, 亦都有時突然會...
# 1853    Raymond Wong 好難捉摸, 有無A+要睇運, 同埋佢成日變卦, assignmen...
# ...

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

data1[data1["teacher"]=="Amy"]["body"]
# Out:
# 383                                   Amy is really nice.
# 892     In general, I can say that it is not the cours...
# 901     Google the quiz answers before lessons so you ...
# 904     Amy真係好好人 每堂都專登搞下笑令課堂更加融洽\n每堂啲online quiz都一定係範圍...
# 909         Register this course if you want low grade :)
# 960        Lesson quiz完全google就OK\n基本上冇workloads\n拎A,B冇難度
# 961                             追hon一定唔好讀每堂EXE基本可以GOOGLE定
# 1210    平時下堂之前會有 quiz，80%題目可以goggle 找到答案，10分拿 7/8分完全沒難...
# 1596    強烈推薦報讀amy既the sky and us\nAmy人非常好 商科人冇phy底 \n無...
# 1772    即使拎A-都唔建議大家reg\n真心伏......\n每次上完堂都要做online MC q...
# 1783    this course is very idiotic\nyou never know wh...
# 1835    Amy\nhea\nkiller \nFinal test 難到hihi (溫左都唔識)\n...
# 1858    一個project （8版ppt), 一份field trip report, 工作量真心少...
# 1975    I have absolutely no idea of how to get high m...
# 2001                                 killer,\n5 ho reg!!!
# 2006    The course is like a joke. Seems only project ...
# ...

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

data1[data1["teacher"]=="張為群"]["body"]
# Out:
# 708         我班groupmate 纏到佢癲 \n不過佢俾D feedback 感覺都好虛\n自求多福
# 2127    唔錯,PJ冇咩限制,可以多D CONSULT佢\npresent&paper一定要多D文獻\...
# 2276                       係多野做但交做曬個grade都唔會太差\n上堂教d野都幾有用
# 2602    1.次次lecture都有堂上作業（當attendance\n2.tutorial分組做口頭...
# 2789    幾多野做下!\n尤其係簡左某D難做既題目 工作量倍增\n不過呢科係學到野!\n比起技巧 文筆...
# 2809    雖然要take attendance 但係上堂好輕鬆\n有中樂底或者鍾意中樂既，上堂會好開心...
# 2821    大課由十三個黎自Department of Chinese and History嘅人教\n...
# 2841                                        如之前既留言，好導師之選。
# 2860    1501既工作量係輕鬆既！\n1) Presentation\n2) 學期報告（論文）\n3...
# 3214    其實大部分CCIV的課程都一樣\n啊SIR 第一堂都講過,\n功課交齊 番足堂 至少有一個B...
# 3473    堂要上足 每堂都有堂課 test又唔難\n上Lecture幾有趣 覺得有意義唔曬我時間\n至...
# 3577    一個Group Presentation\n大課每堂一份堂上功課\n學期報告一份\n學期論文...
# 3578    一個Group Presentation\n大課今堂一份堂上功課\n學期報告一份\n學期論文...
# 3658    今個sem開始轉左計分方法...lecture返足堂會比較好。\n雖然唔點名...但期中同期...
# 3743    大課可以揀馬家輝, 上堂笑到落堂\n徐麗莎悶到嘔白泡導修課好不幸, 成大班強國人reg 左\...
# 3882    諗報告題目好煩\n要多consult tutor\n上堂亦要多d發言拎參與分班中有內地生\n...
# ...

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

data1[data1["teacher"]=="Wong Sai On"]["body"]
